# %% [markdown]
# # Week 4 – Lists, Tuples, and Dictionaries
#
# This notebook contains 5 programming exercises.
# For each exercise:
# 1. Read the description.
# 2. Complete the code in the function stub.
# 3. Run the tests to verify your solution.
#
# > **Submission reminder:** When you are done, go to **File → Download → Download .ipynb** and upload the file to Moodle.

# %% [markdown]
# ## Exercise 1 – Unique Sorted List
#
# Implement `unique_sorted(numbers)` that receives a list of integers and
# returns a **new list** with duplicate values removed and the result sorted
# in ascending order.

# %%
def unique_sorted(numbers):
    """Return a sorted list of unique integers from the input list."""
    # TODO: implement this function
    raise NotImplementedError

# %%
# Tests for unique_sorted
assert unique_sorted([]) == []
assert unique_sorted([1, 1, 1]) == [1]
assert unique_sorted([3, 1, 2, 3, 2]) == [1, 2, 3]
assert unique_sorted([5, -1, 5, 0]) == [-1, 0, 5]
print("✅ unique_sorted: all tests passed.")

# %% [markdown]
# ## Exercise 2 – Min & Max as Tuple
#
# Implement `min_max(numbers)` that receives a **non-empty** list of numbers
# and returns a tuple `(min_value, max_value)`.
#
# * If the list is empty, raise `ValueError`.

# %%
def min_max(numbers):
    """Return (min_value, max_value) for a non-empty list.

    Raise ValueError if the list is empty.
    """
    # TODO: implement this function
    raise NotImplementedError

# %%
# Tests for min_max
assert min_max([1]) == (1, 1)
assert min_max([1, 2, 3]) == (1, 3)
assert min_max([-5, 0, 10]) == (-5, 10)

try:
    min_max([])
except ValueError:
    pass
else:
    raise AssertionError("min_max([]) should raise ValueError")

print("✅ min_max: all tests passed.")

# %% [markdown]
# ## Exercise 3 – Inverting a Dictionary
#
# Implement `invert_dict(d)` that receives a dictionary `d` mapping keys to values,
# and returns a **new dictionary** mapping each value to its key.
#
# You may assume that the values in `d` are unique and hashable.
#
# Example:
# ```python
# invert_dict({'a': 1, 'b': 2})  # -> {1: 'a', 2: 'b'}
# ```

# %%
def invert_dict(d: dict) -> dict:
    """Return a dictionary with keys and values swapped."""
    # TODO: implement this function
    raise NotImplementedError

# %%
# Tests for invert_dict
assert invert_dict({}) == {}
assert invert_dict({'a': 1}) == {1: 'a'}
result = invert_dict({'a': 1, 'b': 2})
assert result == {1: 'a', 2: 'b'}
print("✅ invert_dict: all tests passed.")

# %% [markdown]
# ## Exercise 4 – Group Words by Length
#
# Implement `group_by_length(words)` that receives a list of strings and
# returns a dictionary mapping each **word length** to a list of words of that length.
#
# Example:
# ```python
# group_by_length(["a", "to", "tea"])  # -> {1: ["a"], 2: ["to"], 3: ["tea"]}
# ```

# %%
def group_by_length(words):
    """Group words by their length, return dict {length: [words]}"""
    # TODO: implement this function
    raise NotImplementedError

# %%
# Tests for group_by_length
assert group_by_length([]) == {}
result = group_by_length(["a", "to", "tea", "hi"])
assert result[1] == ["a"]
assert sorted(result[2]) == ["hi", "to"]
assert result[3] == ["tea"]
print("✅ group_by_length: all tests passed.")

# %% [markdown]
# ## Exercise 5 – Grade Statistics (Dict)
#
# Implement `grade_stats(grades)` that receives a non-empty list of numbers
# (0–100) and returns a dictionary with the following keys:
#
# * `'min'` – minimum grade
# * `'max'` – maximum grade
# * `'avg'` – average (float)
# * `'count'` – number of grades

# %%
def grade_stats(grades):
    """Return a dictionary with min, max, avg, and count of grades list."""
    # TODO: implement this function
    raise NotImplementedError

# %%
# Tests for grade_stats
stats = grade_stats([100])
assert stats['min'] == 100 and stats['max'] == 100
assert stats['avg'] == 100 and stats['count'] == 1

stats = grade_stats([70, 80, 90])
assert stats['min'] == 70
assert stats['max'] == 90
assert abs(stats['avg'] - 80.0) < 1e-9
assert stats['count'] == 3

print("✅ grade_stats: all tests passed.")
