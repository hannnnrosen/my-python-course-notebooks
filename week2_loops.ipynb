# %% [markdown]
# # Week 2 – Loops & Conditionals
#
# This notebook contains 5 programming exercises.
# For each exercise:
# 1. Read the description.
# 2. Complete the code in the function stub.
# 3. Run the tests to verify your solution.
#
# > **Submission reminder:** When you are done, go to **File → Download → Download .ipynb** and upload the file to Moodle.

# %% [markdown]
# ## Exercise 1 – Counting Even Numbers
#
# Implement `count_even(numbers)` that receives a list of integers and
# returns how many of them are even.

# %%
def count_even(numbers):
    """Return the number of even integers in the list."""
    # TODO: implement this function using a loop and condition
    raise NotImplementedError

# %%
# Tests for count_even
assert count_even([]) == 0
assert count_even([1, 3, 5]) == 0
assert count_even([2, 4, 6]) == 3
assert count_even([1, 2, 3, 4, 5]) == 2
print("✅ count_even: all tests passed.")

# %% [markdown]
# ## Exercise 2 – Sum of Multiples (3 or 5)
#
# Implement `sum_multiples(n)` that returns the sum of all positive integers
# less than or equal to `n` that are divisible by **3 or 5**.
#
# Example:
# * `n = 10` → `3 + 5 + 6 + 9 + 10 = 33`

# %%
def sum_multiples(n: int) -> int:
    """Return sum of numbers from 1..n that are divisible by 3 or 5."""
    # TODO: implement this function using a loop and if
    raise NotImplementedError

# %%
# Tests for sum_multiples
assert sum_multiples(1) == 0
assert sum_multiples(3) == 3
assert sum_multiples(5) == 8      # 3 + 5
assert sum_multiples(10) == 33    # 3,5,6,9,10
print("✅ sum_multiples: all tests passed.")

# %% [markdown]
# ## Exercise 3 – Prime Numbers
#
# Implement `is_prime(n)` that returns `True` if `n` is a prime number,
# and `False` otherwise.
#
# * `n` is prime if it is greater than 1 and divisible only by 1 and itself.

# %%
def is_prime(n: int) -> bool:
    """Return True if n is prime, False otherwise."""
    # TODO: implement this function using conditions and a loop
    raise NotImplementedError

# %%
# Tests for is_prime
primes = [2, 3, 5, 7, 11, 13, 17, 19]
for p in primes:
    assert is_prime(p) is True

non_primes = [0, 1, 4, 6, 8, 9, 10, 12, 15]
for x in non_primes:
    assert is_prime(x) is False

print("✅ is_prime: all tests passed.")

# %% [markdown]
# ## Exercise 4 – Counting Digits (Loop)
#
# Implement `count_digits(n)` that returns the number of digits in the
# decimal representation of a non-negative integer `n`.
#
# Examples:
# * `count_digits(0) -> 1`
# * `count_digits(9) -> 1`
# * `count_digits(42) -> 2`
# * `count_digits(1234) -> 4`

# %%
def count_digits(n: int) -> int:
    """Return the number of digits of n (base 10)."""
    # TODO: implement this using a loop (do not convert to string)
    raise NotImplementedError

# %%
# Tests for count_digits
assert count_digits(0) == 1
assert count_digits(9) == 1
assert count_digits(42) == 2
assert count_digits(999) == 3
assert count_digits(1000) == 4
print("✅ count_digits: all tests passed.")

# %% [markdown]
# ## Exercise 5 – Text Triangle Pattern
#
# Implement `right_triangle(n)` that returns a single string representing
# a right triangle made of `*` characters, with `n` rows.
#
# For example, `right_triangle(4)` should return the string:
#
# ```text
# *
# **
# ***
# ****
# ```
#
# (including newline characters between rows, but no extra newline at the end).

# %%
def right_triangle(n: int) -> str:
    """Return a string with a right triangle of height n made of '*'."""
    # TODO: implement this using loops
    raise NotImplementedError

# %%
# Tests for right_triangle
assert right_triangle(1) == "*"
assert right_triangle(2) == "*\n**"
assert right_triangle(3) == "*\n**\n***"

print("✅ right_triangle: all tests passed.")
