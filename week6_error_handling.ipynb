# %% [markdown]
# # Week 6 – Error Handling & Debugging
#
# This notebook contains 5 programming exercises.
# For each exercise:
# 1. Read the description.
# 2. Complete the code in the function stub.
# 3. Run the tests to verify your solution.
#
# > **Submission reminder:** When you are done, go to **File → Download → Download .ipynb** and upload the file to Moodle.

# %% [markdown]
# ## Exercise 1 – Safe Integer Conversion
#
# Implement `safe_int(s)` that tries to convert a string `s` to an integer.
#
# * If conversion succeeds, return the integer.
# * If it fails (e.g. `"abc"`), return `None` (do **not** raise).

# %%
def safe_int(s: str):
    """Convert s to int or return None if conversion fails."""
    # TODO: implement this function using try/except
    raise NotImplementedError

# %%
# Tests for safe_int
assert safe_int("10") == 10
assert safe_int("-5") == -5
assert safe_int("0") == 0
assert safe_int("abc") is None
assert safe_int("") is None
print("✅ safe_int: all tests passed.")

# %% [markdown]
# ## Exercise 2 – Safe Division
#
# Implement `safe_divide(a, b)` that returns `a / b`.
#
# * If `b` is zero, return `None` (do **not** raise `ZeroDivisionError`).

# %%
def safe_divide(a: float, b: float):
    """Return a / b, or None if division by zero occurs."""
    # TODO: implement this using try/except
    raise NotImplementedError

# %%
# Tests for safe_divide
assert safe_divide(10, 2) == 5
assert safe_divide(3, 2) == 1.5
assert safe_divide(1, 0) is None
print("✅ safe_divide: all tests passed.")

# %% [markdown]
# ## Exercise 3 – Custom Error Message
#
# Implement `get_item(lst, index)` that returns `lst[index]`.
#
# * If the index is out of range, raise a `ValueError` with a helpful message,
#   instead of the default `IndexError`.

# %%
def get_item(lst, index):
    """Return lst[index], but raise ValueError if index is out of range."""
    # TODO: implement this function with try/except
    raise NotImplementedError

# %%
# Tests for get_item
assert get_item([1, 2, 3], 0) == 1
assert get_item([1, 2, 3], 2) == 3

try:
    get_item([1, 2, 3], 3)
except ValueError as e:
    assert "out of range" in str(e).lower()
else:
    raise AssertionError("Expected ValueError for index out of range")

print("✅ get_item: all tests passed.")

# %% [markdown]
# ## Exercise 4 – Safe File Reading
#
# Implement `read_first_line(path)` that tries to open a text file at `path`
# and returns its first line **without** the trailing newline.
#
# * If the file does not exist, return `None` (do not raise).

# %%
def read_first_line(path: str):
    """Return the first line of file at path, or None if file not found."""
    # TODO: implement this with try/except and file handling
    raise NotImplementedError

# %%
# Tests for read_first_line
# create a temporary file
temp_path = "temp_test_file.txt"
with open(temp_path, "w") as f:
    f.write("Hello\nWorld\n")

assert read_first_line(temp_path) == "Hello"
assert read_first_line("this_file_does_not_exist_12345.txt") is None

print("✅ read_first_line: all tests passed.")

# %% [markdown]
# ## Exercise 5 – Email Validation with Errors
#
# Implement `validate_email(address)` that checks a very simple email rule:
#
# * There must be exactly one `'@'`.
# * There must be at least one `'.'` after the `'@'`.
#
# If the address is valid, return `address` unchanged.
# If it is invalid, raise `ValueError`.

# %%
def validate_email(address: str) -> str:
    """Return address if valid, otherwise raise ValueError."""
    # TODO: implement this function with appropriate checks
    raise NotImplementedError

# %%
# Tests for validate_email
assert validate_email("a@b.com") == "a@b.com"
assert validate_email("user.name@domain.co.il") == "user.name@domain.co.il"

invalid = ["abc", "a@b", "a@@b.com", "a@bcom", "a@.com"]
for addr in invalid:
    try:
        validate_email(addr)
    except ValueError:
        pass
    else:
        raise AssertionError(f"Expected ValueError for {addr!r}")

print("✅ validate_email: all tests passed.")
