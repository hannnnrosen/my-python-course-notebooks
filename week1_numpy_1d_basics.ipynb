# %% [markdown]
# # Week 1 – NumPy 1D Basics
#
# Import NumPy in the first code cell before working on the exercises.

# %%
import numpy as np

# %% [markdown]
# ## Exercise 1 – 1D zeros vector
#
# Write a function `zeros_1d(n)` that returns a 1D NumPy array of length `n` filled with zeros (dtype float).
#
# Example: `zeros_1d(3)` should return something like `[0., 0., 0.]`.

# %%
import numpy as np

def zeros_1d(n: int) -> np.ndarray:
    """Return a 1D NumPy array of length n filled with zeros (float)."""
    # TODO: implement using np.zeros
    raise NotImplementedError

# %%
a = zeros_1d(5)
assert isinstance(a, np.ndarray)
assert a.shape == (5,)
assert np.all(a == 0)
assert a.dtype == float
print('✅ Exercise 1 passed.')

# %% [markdown]
# ## Exercise 2 – 1D ones vector
#
# Write a function `ones_1d(n, dtype=float)` that returns a 1D array of length `n` filled with ones and the given dtype.
#
# Example: `ones_1d(4, dtype=int)` should return `[1, 1, 1, 1]`.

# %%
def ones_1d(n: int, dtype=float) -> np.ndarray:
    """Return a 1D NumPy array of length n filled with ones and given dtype."""
    # TODO: implement using np.ones
    raise NotImplementedError

# %%
x = ones_1d(4, dtype=int)
assert x.shape == (4,)
assert np.all(x == 1)
assert x.dtype == int
y = ones_1d(3)
assert y.dtype == float
print('✅ Exercise 2 passed.')

# %% [markdown]
# ## Exercise 3 – Range with step
#
# Write a function `arange_1d(start, stop, step)` that returns a 1D array with values from `start` (inclusive) to `stop` (exclusive) with the given `step`, using `np.arange`.
#
# Example: `arange_1d(0, 5, 2)` should give `[0, 2, 4]`.

# %%
def arange_1d(start: float, stop: float, step: float) -> np.ndarray:
    """Return a 1D array [start, start+step, ..., < stop]."""
    # TODO: implement using np.arange
    raise NotImplementedError

# %%
a = arange_1d(0, 5, 2)
assert np.array_equal(a, np.array([0, 2, 4]))
b = arange_1d(1, 2, 0.25)
assert np.allclose(b, np.array([1.0, 1.25, 1.5, 1.75]))
print('✅ Exercise 3 passed.')

# %% [markdown]
# ## Exercise 4 – Every second element
#
# Write a function `every_other(arr)` that returns a view of the input 1D array containing every second element starting at index 0.
# Use slicing only.
#
# Example: `every_other(np.array([0,1,2,3,4]))` → `[0, 2, 4]`.

# %%
def every_other(arr: np.ndarray) -> np.ndarray:
    """Return a view with elements arr[0], arr[2], arr[4], ..."""
    # TODO: implement using slicing
    raise NotImplementedError

# %%
x = np.arange(10)
y = every_other(x)
assert np.array_equal(y, np.array([0, 2, 4, 6, 8]))
# Check it is a view
y[0] = 100
assert x[0] == 100
print('✅ Exercise 4 passed.')

# %% [markdown]
# ## Exercise 5 – Positive values only
#
# Write a function `positive_only(arr)` that returns a new 1D array containing only the elements of `arr` that are strictly greater than 0, using boolean indexing.
#
# Example: `positive_only(np.array([-1, 0, 2, 3]))` → `[2, 3]`.

# %%
def positive_only(arr: np.ndarray) -> np.ndarray:
    """Return a new array with only positive elements of arr."""
    # TODO: implement using boolean masks
    raise NotImplementedError

# %%
a = np.array([-2, -1, 0, 1, 2, 3])
res = positive_only(a)
assert np.array_equal(res, np.array([1, 2, 3]))
print('✅ Exercise 5 passed.')
