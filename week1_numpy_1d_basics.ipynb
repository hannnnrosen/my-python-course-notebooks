# %% [markdown]
# # Week 1 – NumPy 1D Basics
# Import NumPy:
# ```python
# import numpy as np
# ```

# %% [markdown]
# ## Exercise 1 – 1D zeros vector
# Write a function `zeros_1d(n)`...

# %%
import numpy as np

def zeros_1d(n):
    # TODO
    raise NotImplementedError

# %%
a=zeros_1d(5)
assert isinstance(a,np.ndarray)
print('OK')

# %% [markdown]
# ## Exercise 2 – ones vector

# %%
def ones_1d(n,dtype=float):
    # TODO
    raise NotImplementedError

# %%
print('Test placeholder')

# %% [markdown]
# ## Exercise 3 – arange

# %%
def arange_1d(start,stop,step):
    # TODO
    raise NotImplementedError

# %%
print('Test placeholder')

# %% [markdown]
# ## Exercise 4 – every other

# %%
def every_other(arr):
    # TODO
    raise NotImplementedError

# %%
print('Test placeholder')

# %% [markdown]
# ## Exercise 5 – positive only

# %%
def positive_only(arr):
    # TODO
    raise NotImplementedError

# %%
print('Test placeholder')
