# %% [markdown]
# # Week 4 – 3D Arrays & Indexing

# %%
import numpy as np

# %% [markdown]
# ## Exercise 16 – Sequential 3D array
#
# Write a function `sequential_3d(shape)` where `shape = (d1, d2, d3)` that returns a 3D array filled with values `0, 1, ..., d1*d2*d3-1` in row-major order.

# %%
def sequential_3d(shape: tuple) -> np.ndarray:
    """Return 3D array with given shape filled with 0..N-1."""
    # TODO: implement using np.arange and reshape
    raise NotImplementedError

# %%
arr = sequential_3d((2, 3, 4))
assert arr.shape == (2, 3, 4)
assert np.array_equal(arr.ravel(), np.arange(24))
print('✅ Exercise 16 passed.')

# %% [markdown]
# ## Exercise 17 – Middle slice along axis
#
# Write a function `middle_slice_3d(arr, axis)` that takes a 3D array and an axis (0, 1, or 2) and returns the slice corresponding to the middle index along that axis.

# %%
def middle_slice_3d(arr: np.ndarray, axis: int) -> np.ndarray:
    """Return middle slice of a 3D array along given axis."""
    # TODO: compute mid index and use slicing
    raise NotImplementedError

# %%
vol = np.arange(4*5*6).reshape(4, 5, 6)
sl0 = middle_slice_3d(vol, axis=0)
assert sl0.shape == (5, 6)
assert np.array_equal(sl0, vol[2, :, :])
print('✅ Exercise 17 passed.')

# %% [markdown]
# ## Exercise 18 – Max projection of a 3D array
#
# Write a function `max_projection_3d(arr, axis)` that returns the maximum value projection along a chosen axis of a 3D array using `np.max`.

# %%
def max_projection_3d(arr: np.ndarray, axis: int) -> np.ndarray:
    """Return max projection of 3D arr along given axis."""
    # TODO: implement using np.max
    raise NotImplementedError

# %%
vol = np.arange(24).reshape(2, 3, 4)
proj = max_projection_3d(vol, axis=0)
assert np.array_equal(proj, np.max(vol, axis=0))
print('✅ Exercise 18 passed.')

# %% [markdown]
# ## Exercise 19 – Stack 2D matrices into 3D
#
# Write a function `stack_matrices(mats)` that takes a list of 2D arrays of the same shape and stacks them into a 3D array using `np.stack` (axis 0).

# %%
def stack_matrices(mats: list) -> np.ndarray:
    """Stack a list of 2D arrays into a 3D array (axis 0)."""
    # TODO: implement using np.stack
    raise NotImplementedError

# %%
M1 = np.ones((2, 2))
M2 = 2 * np.ones((2, 2))
stacked = stack_matrices([M1, M2])
assert stacked.shape == (2, 2, 2)
assert np.array_equal(stacked[0], M1)
assert np.array_equal(stacked[1], M2)
print('✅ Exercise 19 passed.')

# %% [markdown]
# ## Exercise 20 – Pairwise Euclidean distances
#
# Write a function `distance_matrix(points)` that takes a 2D array of shape `(n, d)` with `n` points in `d`-dimensional space and returns an `(n, n)` array `D` where `D[i, j]` is the Euclidean distance between point `i` and point `j` using vectorized operations.

# %%
def distance_matrix(points: np.ndarray) -> np.ndarray:
    """Return pairwise Euclidean distance matrix for points (n, d)."""
    # TODO: implement using broadcasting and np.sum
    raise NotImplementedError

# %%
pts = np.array([[0., 0.],
                [3., 4.],
                [3., 0.]])
D = distance_matrix(pts)
assert np.allclose(np.diag(D), 0)
assert abs(D[0, 1] - 5.0) < 1e-9
assert abs(D[1, 2] - 4.0) < 1e-9
print('✅ Exercise 20 passed.')
