# %% [markdown]
# # Week 3 – Intro Linear Algebra with NumPy

# %%
import numpy as np

# %% [markdown]
# ## Exercise 11 – Dot product (no np.dot)
#
# Write a function `dot_1d(a, b)` that returns the scalar dot product of two 1D arrays `a` and `b` of the same length, without using `np.dot` or `@`. Use elementwise multiplication and `np.sum`.

# %%
def dot_1d(a: np.ndarray, b: np.ndarray) -> float:
    """Return dot product of a and b as a scalar."""
    # TODO: implement using elementwise multiply and np.sum
    raise NotImplementedError

# %%
a = np.array([1., 2., 3.])
b = np.array([4., 5., 6.])
assert abs(dot_1d(a, b) - 32.0) < 1e-9
print('✅ Exercise 11 passed.')

# %% [markdown]
# ## Exercise 12 – Matrix multiplication (2D)
#
# Write a function `matmul_2d(A, B)` that returns the matrix product `A @ B` using NumPy's `@` operator. Assume shapes are compatible.

# %%
def matmul_2d(A: np.ndarray, B: np.ndarray) -> np.ndarray:
    """Return the matrix product A @ B."""
    # TODO: implement using @
    raise NotImplementedError

# %%
A = np.array([[1, 2],
              [3, 4]])
B = np.array([[5, 6],
              [7, 8]])
C = matmul_2d(A, B)
assert np.array_equal(C, A @ B)
print('✅ Exercise 12 passed.')

# %% [markdown]
# ## Exercise 13 – Matrix–vector product
#
# Write a function `matvec(A, x)` that multiplies a 2D matrix `A` of shape `(m, n)` with a 1D vector `x` of shape `(n,)` and returns a result of shape `(m,)`.

# %%
def matvec(A: np.ndarray, x: np.ndarray) -> np.ndarray:
    """Return A @ x for 2D A and 1D x."""
    # TODO: implement using @
    raise NotImplementedError

# %%
A = np.array([[1., 0.],
              [0., 2.]])
x = np.array([3., 4.])
y = matvec(A, x)
assert np.allclose(y, np.array([3., 8.]))
print('✅ Exercise 13 passed.')

# %% [markdown]
# ## Exercise 14 – Solve a linear system
#
# Write a function `solve_linear_system(A, b)` that solves the system `A x = b` for `x` using `np.linalg.solve`. `A` is a square 2D array, `b` is a 1D array.

# %%
def solve_linear_system(A: np.ndarray, b: np.ndarray) -> np.ndarray:
    """Solve A x = b using np.linalg.solve and return x."""
    # TODO: implement
    raise NotImplementedError

# %%
A = np.array([[2., 1.],
              [1., 3.]])
b = np.array([1., 2.])
x = solve_linear_system(A, b)
assert np.allclose(A @ x, b)
print('✅ Exercise 14 passed.')

# %% [markdown]
# ## Exercise 15 – Orthonormal rows
#
# Write a function `rows_orthonormal(Q, tol=1e-8)` that checks whether the rows of a 2D matrix `Q` are approximately orthonormal. That is, `Q @ Q.T` should be close to the identity matrix.

# %%
def rows_orthonormal(Q: np.ndarray, tol: float = 1e-8) -> bool:
    """Return True if rows of Q are approximately orthonormal."""
    # TODO: implement using Q @ Q.T and np.allclose
    raise NotImplementedError

# %%
theta = np.pi / 4
R = np.array([[np.cos(theta), -np.sin(theta)],
              [np.sin(theta),  np.cos(theta)]])
assert rows_orthonormal(R)
bad = np.array([[1., 1.],
                [0., 1.]])
assert not rows_orthonormal(bad)
print('✅ Exercise 15 passed.')
