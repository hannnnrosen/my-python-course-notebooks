# %% [markdown]
# # NumPy 1D, 2D, 3D – 30 Exercises
# Import NumPy:
# ```python
# import numpy as np
# ```

# %% [markdown]
# ## Exercise 1
# Write the function for exercise 1.

# %%
import numpy as np

def exercise_1_func(x):
    # TODO: implement exercise 1
    raise NotImplementedError

# %%
# Test for Exercise 1
print('Exercise 1 placeholder test executed.')

# %% [markdown]
# ## Exercise 2
# Write the function for exercise 2.

# %%
import numpy as np

def exercise_2_func(x):
    # TODO: implement exercise 2
    raise NotImplementedError

# %%
# Test for Exercise 2
print('Exercise 2 placeholder test executed.')

# %% [markdown]
# ## Exercise 3
# Write the function for exercise 3.

# %%
import numpy as np

def exercise_3_func(x):
    # TODO: implement exercise 3
    raise NotImplementedError

# %%
# Test for Exercise 3
print('Exercise 3 placeholder test executed.')

# %% [markdown]
# ## Exercise 4
# Write the function for exercise 4.

# %%
import numpy as np

def exercise_4_func(x):
    # TODO: implement exercise 4
    raise NotImplementedError

# %%
# Test for Exercise 4
print('Exercise 4 placeholder test executed.')

# %% [markdown]
# ## Exercise 5
# Write the function for exercise 5.

# %%
import numpy as np

def exercise_5_func(x):
    # TODO: implement exercise 5
    raise NotImplementedError

# %%
# Test for Exercise 5
print('Exercise 5 placeholder test executed.')

# %% [markdown]
# ## Exercise 6
# Write the function for exercise 6.

# %%
import numpy as np

def exercise_6_func(x):
    # TODO: implement exercise 6
    raise NotImplementedError

# %%
# Test for Exercise 6
print('Exercise 6 placeholder test executed.')

# %% [markdown]
# ## Exercise 7
# Write the function for exercise 7.

# %%
import numpy as np

def exercise_7_func(x):
    # TODO: implement exercise 7
    raise NotImplementedError

# %%
# Test for Exercise 7
print('Exercise 7 placeholder test executed.')

# %% [markdown]
# ## Exercise 8
# Write the function for exercise 8.

# %%
import numpy as np

def exercise_8_func(x):
    # TODO: implement exercise 8
    raise NotImplementedError

# %%
# Test for Exercise 8
print('Exercise 8 placeholder test executed.')

# %% [markdown]
# ## Exercise 9
# Write the function for exercise 9.

# %%
import numpy as np

def exercise_9_func(x):
    # TODO: implement exercise 9
    raise NotImplementedError

# %%
# Test for Exercise 9
print('Exercise 9 placeholder test executed.')

# %% [markdown]
# ## Exercise 10
# Write the function for exercise 10.

# %%
import numpy as np

def exercise_10_func(x):
    # TODO: implement exercise 10
    raise NotImplementedError

# %%
# Test for Exercise 10
print('Exercise 10 placeholder test executed.')

# %% [markdown]
# ## Exercise 11
# Write the function for exercise 11.

# %%
import numpy as np

def exercise_11_func(x):
    # TODO: implement exercise 11
    raise NotImplementedError

# %%
# Test for Exercise 11
print('Exercise 11 placeholder test executed.')

# %% [markdown]
# ## Exercise 12
# Write the function for exercise 12.

# %%
import numpy as np

def exercise_12_func(x):
    # TODO: implement exercise 12
    raise NotImplementedError

# %%
# Test for Exercise 12
print('Exercise 12 placeholder test executed.')

# %% [markdown]
# ## Exercise 13
# Write the function for exercise 13.

# %%
import numpy as np

def exercise_13_func(x):
    # TODO: implement exercise 13
    raise NotImplementedError

# %%
# Test for Exercise 13
print('Exercise 13 placeholder test executed.')

# %% [markdown]
# ## Exercise 14
# Write the function for exercise 14.

# %%
import numpy as np

def exercise_14_func(x):
    # TODO: implement exercise 14
    raise NotImplementedError

# %%
# Test for Exercise 14
print('Exercise 14 placeholder test executed.')

# %% [markdown]
# ## Exercise 15
# Write the function for exercise 15.

# %%
import numpy as np

def exercise_15_func(x):
    # TODO: implement exercise 15
    raise NotImplementedError

# %%
# Test for Exercise 15
print('Exercise 15 placeholder test executed.')

# %% [markdown]
# ## Exercise 16
# Write the function for exercise 16.

# %%
import numpy as np

def exercise_16_func(x):
    # TODO: implement exercise 16
    raise NotImplementedError

# %%
# Test for Exercise 16
print('Exercise 16 placeholder test executed.')

# %% [markdown]
# ## Exercise 17
# Write the function for exercise 17.

# %%
import numpy as np

def exercise_17_func(x):
    # TODO: implement exercise 17
    raise NotImplementedError

# %%
# Test for Exercise 17
print('Exercise 17 placeholder test executed.')

# %% [markdown]
# ## Exercise 18
# Write the function for exercise 18.

# %%
import numpy as np

def exercise_18_func(x):
    # TODO: implement exercise 18
    raise NotImplementedError

# %%
# Test for Exercise 18
print('Exercise 18 placeholder test executed.')

# %% [markdown]
# ## Exercise 19
# Write the function for exercise 19.

# %%
import numpy as np

def exercise_19_func(x):
    # TODO: implement exercise 19
    raise NotImplementedError

# %%
# Test for Exercise 19
print('Exercise 19 placeholder test executed.')

# %% [markdown]
# ## Exercise 20
# Write the function for exercise 20.

# %%
import numpy as np

def exercise_20_func(x):
    # TODO: implement exercise 20
    raise NotImplementedError

# %%
# Test for Exercise 20
print('Exercise 20 placeholder test executed.')

# %% [markdown]
# ## Exercise 21
# Write the function for exercise 21.

# %%
import numpy as np

def exercise_21_func(x):
    # TODO: implement exercise 21
    raise NotImplementedError

# %%
# Test for Exercise 21
print('Exercise 21 placeholder test executed.')

# %% [markdown]
# ## Exercise 22
# Write the function for exercise 22.

# %%
import numpy as np

def exercise_22_func(x):
    # TODO: implement exercise 22
    raise NotImplementedError

# %%
# Test for Exercise 22
print('Exercise 22 placeholder test executed.')

# %% [markdown]
# ## Exercise 23
# Write the function for exercise 23.

# %%
import numpy as np

def exercise_23_func(x):
    # TODO: implement exercise 23
    raise NotImplementedError

# %%
# Test for Exercise 23
print('Exercise 23 placeholder test executed.')

# %% [markdown]
# ## Exercise 24
# Write the function for exercise 24.

# %%
import numpy as np

def exercise_24_func(x):
    # TODO: implement exercise 24
    raise NotImplementedError

# %%
# Test for Exercise 24
print('Exercise 24 placeholder test executed.')

# %% [markdown]
# ## Exercise 25
# Write the function for exercise 25.

# %%
import numpy as np

def exercise_25_func(x):
    # TODO: implement exercise 25
    raise NotImplementedError

# %%
# Test for Exercise 25
print('Exercise 25 placeholder test executed.')

# %% [markdown]
# ## Exercise 26
# Write the function for exercise 26.

# %%
import numpy as np

def exercise_26_func(x):
    # TODO: implement exercise 26
    raise NotImplementedError

# %%
# Test for Exercise 26
print('Exercise 26 placeholder test executed.')

# %% [markdown]
# ## Exercise 27
# Write the function for exercise 27.

# %%
import numpy as np

def exercise_27_func(x):
    # TODO: implement exercise 27
    raise NotImplementedError

# %%
# Test for Exercise 27
print('Exercise 27 placeholder test executed.')

# %% [markdown]
# ## Exercise 28
# Write the function for exercise 28.

# %%
import numpy as np

def exercise_28_func(x):
    # TODO: implement exercise 28
    raise NotImplementedError

# %%
# Test for Exercise 28
print('Exercise 28 placeholder test executed.')

# %% [markdown]
# ## Exercise 29
# Write the function for exercise 29.

# %%
import numpy as np

def exercise_29_func(x):
    # TODO: implement exercise 29
    raise NotImplementedError

# %%
# Test for Exercise 29
print('Exercise 29 placeholder test executed.')

# %% [markdown]
# ## Exercise 30
# Write the function for exercise 30.

# %%
import numpy as np

def exercise_30_func(x):
    # TODO: implement exercise 30
    raise NotImplementedError

# %%
# Test for Exercise 30
print('Exercise 30 placeholder test executed.')
