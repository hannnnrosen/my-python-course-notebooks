# %% [markdown]
# # Week 1 – Variables, Strings, and Basic Math
#
# This notebook contains 5 programming exercises.
# For each exercise:
# 1. Read the description.
# 2. Complete the code in the function stub.
# 3. Run the tests to verify your solution.
#
# > **Submission reminder:** When you are done, go to **File → Download → Download .ipynb** and upload the file to Moodle.

# %% [markdown]
# ## Exercise 1 – Variables & Types
#
# Create three variables:
#
# * `first_name` – a string with your first name
# * `year_of_birth` – an integer
# * `height_cm` – a float (height in centimeters)
#
# Then the function should return a formatted string:
#
# ```text
# "My name is Alice, I was born in 1999 and I am 172.5 cm tall."
# ```
#
# Replace the example values with the function arguments.

# %%
def describe_person(first_name, year_of_birth, height_cm):
    """Return a formatted description string.

    Example:
    >>> describe_person("Alice", 1999, 172.5)
    'My name is Alice, I was born in 1999 and I am 172.5 cm tall.'
    """
    # TODO: implement this function
    raise NotImplementedError

# %%
# Tests for describe_person
result = describe_person("Alice", 1999, 172.5)
assert isinstance(result, str)
assert "Alice" in result
assert "1999" in result
assert "172.5" in result

result2 = describe_person("Bob", 2000, 180.0)
assert "Bob" in result2 and "2000" in result2 and "180.0" in result2

print("✅ describe_person: all tests passed.")

# %% [markdown]
# ## Exercise 2 – String Manipulation (Initials)
#
# Write a function `initials(full_name)` that receives a full name string,
# for example `"Ada Lovelace"`, and returns the initials in uppercase with dots:
#
# * `"Ada Lovelace"` → `"A.L."`
# * `"grace hopper"` → `"G.H."`
#
# Assume there are exactly two words separated by a space.

# %%
def initials(full_name: str) -> str:
    """Return the initials (with dots) of the given full name."""
    # TODO: implement this function
    raise NotImplementedError

# %%
# Tests for initials
assert initials("Ada Lovelace") == "A.L."
assert initials("grace hopper") == "G.H."
assert initials("Alan Turing") == "A.T."
print("✅ initials: all tests passed.")

# %% [markdown]
# ## Exercise 3 – Basic Math: Circle Area
#
# Write a function `circle_area(radius)` that returns the area of a circle
# with the given radius, using the formula:
#
# \( area = \pi r^2 \)
#
# Use `math.pi` from the standard library.
# The function should:
#
# * Accept a non-negative float or int as `radius`
# * Return a float (the area)

# %%
import math

def circle_area(radius: float) -> float:
    """Return the area of a circle with the given radius."""
    # TODO: implement this function
    raise NotImplementedError

# %%
# Tests for circle_area
a1 = circle_area(0)
assert abs(a1 - 0.0) < 1e-9

a2 = circle_area(1)
assert abs(a2 - math.pi) < 1e-9

a3 = circle_area(2.5)
assert abs(a3 - (math.pi * 2.5 * 2.5)) < 1e-9

print("✅ circle_area: all tests passed.")

# %% [markdown]
# ## Exercise 4 – Temperature Conversion
#
# Implement two functions:
#
# * `c_to_f(c)` – convert Celsius to Fahrenheit using: `F = C * 9/5 + 32`
# * `f_to_c(f)` – convert Fahrenheit to Celsius using: `C = (F - 32) * 5/9`
#
# Both should return floats.

# %%
def c_to_f(c: float) -> float:
    """Convert Celsius to Fahrenheit."""
    # TODO: implement this function
    raise NotImplementedError


def f_to_c(f: float) -> float:
    """Convert Fahrenheit to Celsius."""
    # TODO: implement this function
    raise NotImplementedError

# %%
# Tests for temperature conversion
assert abs(c_to_f(0) - 32) < 1e-9
assert abs(c_to_f(100) - 212) < 1e-9

assert abs(f_to_c(32) - 0) < 1e-9
assert abs(f_to_c(212) - 100) < 1e-9

# round trip
for c in [-40, 0, 37, 100]:
    assert abs(f_to_c(c_to_f(c)) - c) < 1e-9

print("✅ temperature conversion: all tests passed.")

# %% [markdown]
# ## Exercise 5 – String & Character Statistics
#
# Write a function `text_stats(s)` that receives a string `s` and returns a tuple:
#
# ```python
# (length, num_spaces, num_vowels)
# ```
#
# * `length` – total number of characters
# * `num_spaces` – how many spaces `' '` appear
# * `num_vowels` – how many characters are in `'aeiouAEIOU'`

# %%
def text_stats(s: str):
    """Return (length, num_spaces, num_vowels) for the given string."""
    # TODO: implement this function
    raise NotImplementedError

# %%
# Tests for text_stats
assert text_stats("") == (0, 0, 0)
assert text_stats("a") == (1, 0, 1)
assert text_stats("b c") == (3, 1, 0)

length, spaces, vowels = text_stats("Hello World")
assert length == 11
assert spaces == 1
assert vowels == 3  # e, o, o

print("✅ text_stats: all tests passed.")
