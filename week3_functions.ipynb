# %% [markdown]
# # Week 3 – Functions
#
# This notebook contains 5 programming exercises.
# For each exercise:
# 1. Read the description.
# 2. Complete the code in the function stub.
# 3. Run the tests to verify your solution.
#
# > **Submission reminder:** When you are done, go to **File → Download → Download .ipynb** and upload the file to Moodle.

# %% [markdown]
# ## Exercise 1 – Distance Between Points
#
# Implement `distance_2d(x1, y1, x2, y2)` that returns the Euclidean distance
# between two points `(x1, y1)` and `(x2, y2)`.
#
# Use the formula:
#
# \( d = \sqrt{(x2 - x1)^2 + (y2 - y1)^2} \)

# %%
import math

def distance_2d(x1, y1, x2, y2) -> float:
    """Return the Euclidean distance between two 2D points."""
    # TODO: implement this function
    raise NotImplementedError

# %%
# Tests for distance_2d
assert abs(distance_2d(0, 0, 0, 0) - 0) < 1e-9
assert abs(distance_2d(0, 0, 3, 4) - 5) < 1e-9
assert abs(distance_2d(1, 1, 4, 5) - 5) < 1e-9
print("✅ distance_2d: all tests passed.")

# %% [markdown]
# ## Exercise 2 – Factorial
#
# Implement `factorial(n)` that returns `n!` for a non-negative integer `n`.
#
# * Use a loop (do not use recursion or the `math.factorial` function).
# * By definition: `0! = 1`.

# %%
def factorial(n: int) -> int:
    """Return n! for n >= 0."""
    # TODO: implement this function using a loop
    raise NotImplementedError

# %%
# Tests for factorial
values = {0: 1, 1: 1, 2: 2, 3: 6, 5: 120, 7: 5040}
for n, expected in values.items():
    assert factorial(n) == expected
print("✅ factorial: all tests passed.")

# %% [markdown]
# ## Exercise 3 – Average with Validation
#
# Implement `average(numbers)` that receives a **non-empty** list of numbers
# and returns their arithmetic mean.
#
# * If the list is empty, raise a `ValueError`.

# %%
def average(numbers) -> float:
    """Return the arithmetic mean of the numbers list.

    Raise ValueError if the list is empty.
    """
    # TODO: implement this function
    raise NotImplementedError

# %%
# Tests for average
assert abs(average([1, 2, 3]) - 2.0) < 1e-9
assert abs(average([10, 20]) - 15.0) < 1e-9

# test empty list raises
try:
    average([])
except ValueError:
    pass
else:
    raise AssertionError("average([]) should raise ValueError")

print("✅ average: all tests passed.")

# %% [markdown]
# ## Exercise 4 – Cleaning and Joining Words
#
# Implement `clean_join(words)` that receives a list of words (strings),
# removes any empty strings and surrounding whitespace from each word,
# and returns a single string with the cleaned words joined by a single space.
#
# Example:
# ```python
# clean_join(["  hello", "", "world  "])  # -> "hello world"
# ```

# %%
def clean_join(words):
    """Return a space-separated string of non-empty, trimmed words."""
    # TODO: implement this function
    raise NotImplementedError

# %%
# Tests for clean_join
assert clean_join([]) == ""
assert clean_join(["hello"]) == "hello"
assert clean_join(["  hello", "", "world  "]) == "hello world"
assert clean_join([" a ", " b ", " ", "c"]) == "a b c"
print("✅ clean_join: all tests passed.")

# %% [markdown]
# ## Exercise 5 – Function Composition (Temperature)
#
# Implement `round_trip_temperature(c)` that:
#
# 1. Converts `c` from Celsius to Fahrenheit.
# 2. Converts back from Fahrenheit to Celsius.
# 3. Returns the final Celsius value.
#
# Reuse your own helper functions `c_to_f` and `f_to_c` **in this week** (redefine them here),
# and check how close the round-trip result is to the original `c`.

# %%
def c_to_f(c: float) -> float:
    """Convert Celsius to Fahrenheit."""
    # TODO: implement this function
    raise NotImplementedError


def f_to_c(f: float) -> float:
    """Convert Fahrenheit to Celsius."""
    # TODO: implement this function
    raise NotImplementedError


def round_trip_temperature(c: float) -> float:
    """Convert c -> F -> C and return the final Celsius value."""
    # TODO: implement this function using c_to_f and f_to_c
    raise NotImplementedError

# %%
# Tests for round_trip_temperature (and helpers)
for c in [-40, 0, 37, 100]:
    c2 = round_trip_temperature(c)
    assert abs(c2 - c) < 1e-9

print("✅ round_trip_temperature: all tests passed.")
